# %%
import pandas as pd

# %%
df = pd.read_excel("data/test.xlsx")

# %%
df.head()
# Out:
#               Amazon             Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0  Bottom Size Value  Bottoms Size to Range     Inseam  Body Type
# 1           Required               Optional   Optional   Required
# 2                  4                      4         20    Regular
# 3                  6                      6         21       Plus
# 4                  8                      8         22       Slim
#
#     Unnamed: 4          Ebay   Unnamed: 6   Unnamed: 7            Debenhams  \
# 0  Height Type  Trouser Size   Inside Leg    Size Type  size wtrousersjeans
# 1     Required      Required  Recommended  Recommended             Required
# 2      Regular            10       101 cm   Big & Tall                   10
# 3   Extra Tall          10XL       102 cm      Regular                10-12
# 4         Tall            12       103 cm          NaN               10-12L
#
#    Unnamed: 9 SKU 1 Unnamed: 11  Unnamed: 12  Unnamed: 13         SKU 2  \
# ...

# %%
df.
